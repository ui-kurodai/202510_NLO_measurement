# %% [markdown]
# # Add ND filter / boxcar metadata to past measurements
#
# この notebook は PyQt6 ベースの GUI を起動して、実験フォルダ以下の `*.json` に `ND フィルタ` と `boxcar 感度` を追記します。透過率は台帳に登録した CSV から 2 倍波長の点を読み、使えない場合は公称 OD にフォールバックします。

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "measurement_metadata.py").exists():
    REPO_ROOT = REPO_ROOT.parent
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from IPython import get_ipython
from data_maintenance.filter_boxcar_metadata_tool import launch_filter_boxcar_metadata_dialog

ip = get_ipython()
if ip is not None:
    ip.run_line_magic("gui", "qt")

_filter_boxcar_tool = launch_filter_boxcar_metadata_dialog()
_filter_boxcar_tool
